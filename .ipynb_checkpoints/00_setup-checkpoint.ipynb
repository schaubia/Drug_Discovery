# %% [markdown]
# # 00 — Environment Setup & Verification
# **Drug Discovery Pipeline | RTX 3070 Optimized**
#
# This notebook:
# 1. Installs all required packages
# 2. Verifies GPU access and VRAM budget
# 3. Configures mixed precision and memory settings
# 4. Initializes CodeCarbon energy tracking
# 5. Runs a smoke test on every major dependency
#
# > Run this **once** before any other notebook. If all cells pass, your environment is ready.

# %% [markdown]
# ## 1. Install Dependencies
# Run this cell first. It installs everything needed across all 5 notebooks.
# Expected time: ~5-10 minutes on first run.

# %%
# Core scientific stack
import subprocess, sys

def install(package):
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q', package])

packages = [
    # Data & ML
    'numpy',
    'pandas',
    'scikit-learn',
    'scipy',

    # Chemistry
    'rdkit',                    # Molecular featurization
    'PyTDC',                    # TDC datasets (EGFR benchmark)

    # Deep learning (PyTorch-based)
    'torch',                    # Base — install CUDA version manually if needed
    'torch-geometric',          # Graph neural networks
    'deepchem',                 # MPNN, GCN models

    # Transformer model
    'transformers',             # ChemBERTa-2
    'datasets',
    'tokenizers',

    # Energy & resource tracking
    'codecarbon',               # CO2 / energy monitoring
    'psutil',                   # CPU/RAM monitoring
    'gpustat',                  # GPU VRAM monitoring
    'pynvml',                   # NVIDIA management library

    # Optimization
    'optuna',                   # Hyperparameter search

    # Visualization
    'matplotlib',
    'seaborn',
    'plotly',
    'umap-learn',               # Chemical space visualization

    # Utilities
    'tqdm',
    'ipywidgets',
    'joblib',
]

print('Installing packages...')
for pkg in packages:
    try:
        install(pkg)
        print(f'  ✓ {pkg}')
    except Exception as e:
        print(f'  ✗ {pkg} — {e}')

print('\nDone. Check for any ✗ above and install manually if needed.')

# %% [markdown]
# ## 2. GPU Verification
# Checks that PyTorch can see your RTX 3070 and reports available VRAM.

# %%
import torch

print('='*55)
print('GPU VERIFICATION')
print('='*55)

if torch.cuda.is_available():
    device = torch.device('cuda')
    gpu_name = torch.cuda.get_device_name(0)
    total_vram = torch.cuda.get_device_properties(0).total_memory / 1e9
    free_vram = (torch.cuda.get_device_properties(0).total_memory 
                 - torch.cuda.memory_allocated(0)) / 1e9
    
    print(f'  GPU:        {gpu_name}')
    print(f'  VRAM Total: {total_vram:.1f} GB')
    print(f'  VRAM Free:  {free_vram:.1f} GB')
    print(f'  CUDA:       {torch.version.cuda}')
    print(f'  PyTorch:    {torch.__version__}')
    print()

    # RTX 3070 has 8GB VRAM — warn if less than expected
    if total_vram < 7.5:
        print('  ⚠ WARNING: Expected ~8GB for RTX 3070')
        print('  ⚠ Some models may need batch size reduction')
    else:
        print('  ✓ RTX 3070 detected — 8GB VRAM budget confirmed')
        print('  ✓ Mixed precision (FP16) will be enabled by default')
        print('  ✓ Gradient checkpointing available for large models')
else:
    device = torch.device('cpu')
    print('  ✗ CUDA not available — running on CPU')
    print('  → Install CUDA-enabled PyTorch:')
    print('    pip install torch --index-url https://download.pytorch.org/whl/cu121')

print('='*55)
print(f'  Active device: {device}')
print('='*55)

# %% [markdown]
# ## 3. Memory Configuration
# Sets up optimal memory settings for the RTX 3070's 8GB VRAM budget.

# %%
import torch
import os

# ── Mixed Precision (AMP) ────────────────────────────────────────
# Cuts VRAM usage ~40-60% on RTX 3070 with minimal accuracy loss
# Uses FP16 for forward pass, FP32 for gradients
USE_AMP = torch.cuda.is_available()
scaler = torch.cuda.amp.GradScaler(enabled=USE_AMP)

print('Mixed Precision (AMP):', '✓ ENABLED' if USE_AMP else '✗ disabled (CPU mode)')

# ── Memory Fragmentation Fix ─────────────────────────────────────
# Reduces OOM errors during training by improving allocator behavior
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'
print('Memory Allocator:      ✓ expandable_segments enabled')

# ── Benchmark Mode ──────────────────────────────────────────────
# cudnn finds optimal conv algorithms — good since input shapes are fixed
torch.backends.cudnn.benchmark = True
print('cuDNN Benchmark Mode:  ✓ enabled')

# ── VRAM Budget per Model ────────────────────────────────────────
# Estimated VRAM usage on RTX 3070 (8GB) with AMP enabled
print()
print('Estimated VRAM per model (with AMP):')
vram_budget = {
    'RF + Morgan FP':   '< 0.1 GB  (CPU model — no GPU needed)',
    'AttentiveFP':      '~ 1.2 GB  (safe)',
    'MPNN (DeepChem)':  '~ 2.5 GB  (safe)',
    'ChemBERTa-2':      '~ 5.0 GB  (safe with AMP)',
}
for model, budget in vram_budget.items():
    print(f'  {model:<20} {budget}')

print()
print('All 4 models fit within RTX 3070 VRAM budget.')
print('Config saved to global scope — will be imported by other notebooks.')

# ── Save config dict for other notebooks ────────────────────────
GPU_CONFIG = {
    'device': device,
    'use_amp': USE_AMP,
    'scaler': scaler,
    'batch_size': 64,        # Safe default for RTX 3070
    'num_workers': 4,        # DataLoader workers
    'pin_memory': True,
}

# %% [markdown]
# ## 4. CodeCarbon — Energy Tracking Setup
# Tracks CO2 emissions and energy consumption per model.
# This is key for our efficiency benchmark.

# %%
from codecarbon import EmissionsTracker
import json, os

# ── Configure tracker ───────────────────────────────────────────
# Bulgaria uses EU grid — set country for accurate CO2 estimates
CARBON_CONFIG = {
    'project_name': 'drug_discovery_benchmark',
    'country_iso_code': 'BGR',        # Bulgaria
    'region': None,
    'output_dir': './results/',
    'output_file': 'emissions.csv',
    'save_to_file': True,
    'log_level': 'warning',           # Suppress info noise
    'measure_power_secs': 10,         # Sample every 10s
    'tracking_mode': 'process',
}

# ── Test tracker with a short run ───────────────────────────────
print('Testing CodeCarbon tracker...')
os.makedirs('./results', exist_ok=True)

tracker = EmissionsTracker(**CARBON_CONFIG)
tracker.start()

# Dummy workload
import torch
if torch.cuda.is_available():
    x = torch.randn(1000, 1000, device='cuda')
    _ = x @ x
    del x
    torch.cuda.empty_cache()

emissions = tracker.stop()

print(f'  ✓ Tracker working')
print(f'  Emissions from test run: {emissions * 1000:.4f} mg CO2')
print(f'  Results will be saved to: ./results/emissions.csv')
print()
print('Usage in other notebooks:')
print('  tracker = EmissionsTracker(**CARBON_CONFIG)')
print('  tracker.start(task_name="rf_training")')
print('  # ... train model ...')
print('  emissions = tracker.stop()  # returns kg CO2')

# %% [markdown]
# ## 5. Dependency Smoke Tests
# Verifies every major library imports and runs a minimal operation.

# %%
import importlib

results = {}

# ── RDKit ───────────────────────────────────────────────────────
try:
    from rdkit import Chem
    from rdkit.Chem import Descriptors, AllChem
    mol = Chem.MolFromSmiles('CC(=O)Oc1ccccc1C(=O)O')  # Aspirin
    assert mol is not None
    fp = AllChem.GetMorganFingerprintAsBitVect(mol, radius=2, nBits=2048)
    mw = Descriptors.MolWt(mol)
    results['RDKit'] = f'✓  Aspirin MW={mw:.1f}, FP len={len(fp)}'
except Exception as e:
    results['RDKit'] = f'✗  {e}'

# ── PyTDC ───────────────────────────────────────────────────────
try:
    from tdc.single_pred import ADME
    results['PyTDC'] = '✓  Imported successfully'
except Exception as e:
    results['PyTDC'] = f'✗  {e}'

# ── DeepChem ────────────────────────────────────────────────────
try:
    import deepchem as dc
    results['DeepChem'] = f'✓  v{dc.__version__}'
except Exception as e:
    results['DeepChem'] = f'✗  {e}'

# ── Transformers / ChemBERTa ─────────────────────────────────────
try:
    from transformers import AutoTokenizer
    import transformers
    results['Transformers'] = f'✓  v{transformers.__version__}'
except Exception as e:
    results['Transformers'] = f'✗  {e}'

# ── PyTorch Geometric ────────────────────────────────────────────
try:
    import torch_geometric
    results['PyTorch Geometric'] = f'✓  v{torch_geometric.__version__}'
except Exception as e:
    results['PyTorch Geometric'] = f'✗  {e}'

# ── Optuna ──────────────────────────────────────────────────────
try:
    import optuna
    results['Optuna'] = f'✓  v{optuna.__version__}'
except Exception as e:
    results['Optuna'] = f'✗  {e}'

# ── UMAP ────────────────────────────────────────────────────────
try:
    import umap
    results['UMAP'] = '✓  Imported successfully'
except Exception as e:
    results['UMAP'] = f'✗  {e}'

# ── Print Results ────────────────────────────────────────────────
print('='*55)
print('SMOKE TEST RESULTS')
print('='*55)
all_passed = True
for lib, status in results.items():
    print(f'  {lib:<22} {status}')
    if status.startswith('✗'):
        all_passed = False

print('='*55)
if all_passed:
    print('  ALL TESTS PASSED — ready for 01_data.ipynb')
else:
    print('  SOME TESTS FAILED — fix ✗ items before continuing')

# %% [markdown]
# ## 6. Project Config — Save for All Notebooks
# Central config file used by notebooks 01-05.

# %%
import json, os

CONFIG = {
    # Hardware
    'gpu': 'RTX 3070',
    'vram_gb': 8,
    'use_amp': True,              # Mixed precision — keep True for RTX 3070
    
    # Training
    'batch_size': 64,             # Reduce to 32 if OOM errors occur
    'num_workers': 4,
    'random_seed': 42,
    'test_size': 0.2,
    'val_size': 0.1,
    
    # Target
    'target': 'EGFR',
    'tdc_dataset': 'EGFR_DrugBankFull',  # TDC dataset name
    'task': 'regression',                 # Predicting IC50 values
    
    # Models to compare
    'models': [
        'rf_morgan',              # Random Forest + Morgan fingerprints
        'attentivefp',            # AttentiveFP (PyG)
        'mpnn_deepchem',          # MPNN via DeepChem
        'chemberta2',             # ChemBERTa-2 (HuggingFace)
    ],
    
    # Paths
    'data_dir': './data/',
    'model_dir': './models/',
    'results_dir': './results/',
    
    # Energy tracking
    'country_iso': 'BGR',         # Bulgaria
    
    # Benchmark reference (GPT-Rosalind public scores)
    'gpt_rosalind_bixbench': None,  # Will fill in from paper when available
}

os.makedirs('./data', exist_ok=True)
os.makedirs('./models', exist_ok=True)
os.makedirs('./results', exist_ok=True)
os.makedirs('./utils', exist_ok=True)

with open('./config.json', 'w') as f:
    json.dump(CONFIG, f, indent=2, default=str)

print('config.json saved.')
print()
print('Project structure:')
for root, dirs, files in os.walk('.'):
    # Skip hidden and cache dirs
    dirs[:] = [d for d in dirs if not d.startswith('.') and d != '__pycache__']
    level = root.replace('.', '').count(os.sep)
    indent = '  ' * level
    print(f'{indent}{os.path.basename(root)}/')
    subindent = '  ' * (level + 1)
    for file in files:
        print(f'{subindent}{file}')

# %% [markdown]
# ## 7. GPU Benchmark — Baseline Speed Test
# Records your GPU's baseline performance before any model training.
# Used as a reference point in the final benchmark report.

# %%
import torch
import time
import numpy as np

if not torch.cuda.is_available():
    print('Skipping GPU benchmark — no CUDA available')
else:
    device = torch.device('cuda')
    results_bench = {}

    print('Running GPU baseline benchmark...')
    print()

    # ── FP32 Matrix Multiply ─────────────────────────────────────
    sizes = [512, 1024, 2048, 4096]
    for n in sizes:
        a = torch.randn(n, n, device=device)
        b = torch.randn(n, n, device=device)
        torch.cuda.synchronize()
        t0 = time.time()
        for _ in range(10):
            c = a @ b
        torch.cuda.synchronize()
        elapsed = (time.time() - t0) / 10 * 1000
        results_bench[f'FP32 matmul {n}x{n}'] = f'{elapsed:.2f} ms'
        del a, b, c

    # ── FP16 Matrix Multiply ─────────────────────────────────────
    for n in sizes:
        a = torch.randn(n, n, device=device, dtype=torch.float16)
        b = torch.randn(n, n, device=device, dtype=torch.float16)
        torch.cuda.synchronize()
        t0 = time.time()
        for _ in range(10):
            c = a @ b
        torch.cuda.synchronize()
        elapsed = (time.time() - t0) / 10 * 1000
        results_bench[f'FP16 matmul {n}x{n}'] = f'{elapsed:.2f} ms'
        del a, b, c

    torch.cuda.empty_cache()

    print('FP32 (standard precision):')
    for k, v in results_bench.items():
        if 'FP32' in k:
            print(f'  {k:<30} {v}')

    print()
    print('FP16 (mixed precision — what we will use):')
    for k, v in results_bench.items():
        if 'FP16' in k:
            print(f'  {k:<30} {v}')

    print()
    print('FP16 should be ~2x faster than FP32 on RTX 3070 Tensor Cores.')
    print('This confirms AMP is worth enabling for all models.')

    # Save baseline
    import json
    with open('./results/gpu_baseline.json', 'w') as f:
        json.dump(results_bench, f, indent=2)
    print()
    print('Baseline saved to results/gpu_baseline.json')

# %% [markdown]
# ## ✓ Setup Complete
#
# If all cells above ran without errors, your environment is fully configured.
#
# **Next step:** Open `01_data.ipynb` to load the EGFR dataset from TDC.
#
# ---
# ### Quick Reference — RTX 3070 Tips
#
# | Problem | Solution |
# |---|---|
# | `CUDA out of memory` | Reduce `batch_size` in config.json from 64 → 32 |
# | Training very slow | Check `USE_AMP=True` and `torch.backends.cudnn.benchmark=True` |
# | High VRAM from previous run | `torch.cuda.empty_cache()` between models |
# | DeepChem not finding GPU | Run `import deepchem as dc; dc.utils.get_default_device()` |
#
# ### Energy Tracking Quick Reference
#
# ```python
# from codecarbon import EmissionsTracker
#
# tracker = EmissionsTracker(project_name='model_name', country_iso_code='BGR',
#                            output_dir='./results/', log_level='warning')
# tracker.start()
# # ... your training code ...
# kg_co2 = tracker.stop()
# ```
